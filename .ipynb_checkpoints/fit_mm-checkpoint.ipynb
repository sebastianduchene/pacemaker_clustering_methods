# %%
import os, sys, re
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pylab
from pylab import rcParams
from sklearn import mixture
import scipy.stats as sp
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial import distance
import scipy.stats as sc
from GMM_trees import *
import itertools
# %pylab inline
pylab.rcParams['figure.figsize'] = (20, 5)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
execfile('GMM_trees.py')
#os.listdir('.')

# %%
mm_dat = pd.DataFrame(rescale_data(np.array(pd.read_csv('mammal_matrix.csv'))))

# %%
mm_dat.transpose().plot(legend = False, linewidth = 2, alpha = 0.5)

# %%
#mm_GMM = fit_GMM(np.array(mm_dat))
mm_VGMM = fit_VBGMM(np.array(mm_dat))
mm_DPGMM = fit_DPGMM(np.array(mm_dat))
# Out:
# fitting 10 clusters
# fitting 20 clusters
# fitting 30 clusters
# fitting 40 clusters
# fitting 50 clusters
# fitting 60 clusters
# fitting 70 clusters
# fitting 80 clusters
# fitting 90 clusters
# fitting 100 clusters
# fitting 110 clusters
# fitting 120 clusters
# fitting 130 clusters
# fitting 140 clusters
# fitting 150 clusters
# fitting 160 clusters
# fitting 170 clusters
# fitting 180 clusters
# fitting 190 clusters
# fitting 200 clusters
# fitting 210 clusters
# fitting 220 clusters
# fitting 230 clusters
# fitting 240 clusters
# fitting 250 clusters
# fitting 260 clusters
# fitting 270 clusters
# fitting 280 clusters
# fitting 290 clusters
# fitting 300 clusters
# fitting 310 clusters
# fitting 320 clusters
# fitting 330 clusters
# fitting 340 clusters
# fitting 350 clusters
# fitting 360 clusters
# fitting 370 clusters
# fitting 380 clusters
# fitting 390 clusters
# fitting 400 clusters
# fitting 410 clusters
# fitting 420 clusters

# %%
print mm_VGMM[2]
print mm_DPGMM[2]
# Out:
#   covariance_type           BIC  clusters_used  n_components
# 0        diagonal  75396.829169              3             3
# 1       spherical  57622.368229              2             2
#   covariance_type            BIC  clusters_used  n_components
# 0        diagonal  362361.165075              8           430
# 1       spherical  206216.164434              3           430

# %%
samples_temp_2 = simulate_data(mm_dat, 2, 'spherical', 100)

# %%
samples_temp_8 = simulate_data(mm_dat, 8, 'spherical', 100)

# %%
for i in range(len(samples_temp_8)):
    pd.DataFrame(samples_temp_2[i]).to_csv('sim_mammals/sim_'+str(i)+'.csv')
    pd.DataFrame(samples_temp_8[i]).to_csv('sim_mammals/sim_'+str(i)+'.csv')

# %%
mm_sims_2 = fit_sim_models(samples_temp_2)
mm_sims_2.to_csv('mm_sims_2.csv')
# Out:
# fitting 10 clusters
# fitting 20 clusters
# fitting 30 clusters
# fitting 40 clusters
# fitting 50 clusters
# fitting 60 clusters
# fitting 70 clusters
# fitting 80 clusters
# fitting 90 clusters
# fitting 100 clusters
# fitting 110 clusters
# fitting 120 clusters
# fitting 130 clusters
# fitting 140 clusters
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-b260ce747ee1> in <module>()
# ----> 1 mm_sims_2 = fit_sim_models(samples_temp_2)
#       2 mm_sims_2.to_csv('mm_sims_2.csv')
#
# /Users/sebastianduchene/Desktop/sandbox/pacemaker_clustering_methods/GMM_trees.pyc in fit_sim_models(simulated_data)
#     184     results_mat = pd.DataFrame(np.empty(shape = (len(simulated_data), 2)))
#     185
# --> 186     for i in range(len(simulated_data)):
#     187         fit_temp_vbgmm = fit_VBGMM(simulated_data[i])
#     188         fit_temp_dpp = fit_DPGMM(simulated_data[i])
#
# /Users/sebastianduchene/Desktop/sandbox/pacemaker_clustering_methods/GMM_trees.pyc in fit_VBGMM(br_matrix, svd_transform, standard_matrix)
#      97     for n_c in range(1, data_fit.shape[0] - 3):
#      98         if n_c % 10 == 0:
# ---> 99             print 'fitting %s clusters' %n_c
#     100         diag_models.append(mixture.VBGMM(n_components = n_c, covariance_type = 'diag', n_iter = 1000).fit(data_fit))
#     101         spher_models.append(mixture.VBGMM(n_components = n_c, covariance_type = 'spherical', n_iter = 1000).fit(data_fit))
#
# //anaconda/lib/python2.7/site-packages/sklearn/mixture/dpgmm.pyc in fit(self, X, y)
#     522             self.means_ = cluster.KMeans(
#     523                 n_clusters=self.n_components,
# --> 524                 random_state=self.random_state_).fit(X).cluster_centers_[::-1]
#     525
#     526         if 'w' in self.init_params or not hasattr(self, 'weights_'):
#
# //anaconda/lib/python2.7/site-packages/sklearn/cluster/k_means_.pyc in fit(self, X, y)
#     792                 precompute_distances=self.precompute_distances,
#     793                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
# --> 794                 n_jobs=self.n_jobs)
#     795         return self
#     796
#
# //anaconda/lib/python2.7/site-packages/sklearn/cluster/k_means_.pyc in k_means(X, n_clusters, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, return_n_iter)
#     299                 X, n_clusters, max_iter=max_iter, init=init, verbose=verbose,
#     300                 precompute_distances=precompute_distances, tol=tol,
# --> 301                 x_squared_norms=x_squared_norms, random_state=random_state)
#     302             # determine if these results are the best so far
#     303             if best_inertia is None or inertia < best_inertia:
#
# //anaconda/lib/python2.7/site-packages/sklearn/cluster/k_means_.pyc in _kmeans_single(X, n_clusters, x_squared_norms, max_iter, init, verbose, random_state, tol, precompute_distances)
#     422             _labels_inertia(X, x_squared_norms, centers,
#     423                             precompute_distances=precompute_distances,
# --> 424                             distances=distances)
#     425
#     426         # computation of the means is also called the M-step of EM
#
# //anaconda/lib/python2.7/site-packages/sklearn/cluster/k_means_.pyc in _labels_inertia(X, x_squared_norms, centers, precompute_distances, distances)
#     540         if precompute_distances:
#     541             return _labels_inertia_precompute_dense(X, x_squared_norms,
# --> 542                                                     centers, distances)
#     543         inertia = _k_means._assign_labels_array(
#     544             X, x_squared_norms, centers, labels, distances=distances)
#
# //anaconda/lib/python2.7/site-packages/sklearn/cluster/k_means_.pyc in _labels_inertia_precompute_dense(X, x_squared_norms, centers, distances)
#     477     k = centers.shape[0]
#     478     all_distances = euclidean_distances(centers, X, x_squared_norms,
# --> 479                                         squared=True)
#     480     labels = np.empty(n_samples, dtype=np.int32)
#     481     labels.fill(-1)
#
# //anaconda/lib/python2.7/site-packages/sklearn/metrics/pairwise.pyc in euclidean_distances(X, Y, Y_norm_squared, squared)
#     205         XX = row_norms(X, squared=True)[:, np.newaxis]
#     206
# --> 207     distances = safe_sparse_dot(X, Y.T, dense_output=True)
#     208     distances *= -2
#     209     distances += XX
#
# KeyboardInterrupt:
